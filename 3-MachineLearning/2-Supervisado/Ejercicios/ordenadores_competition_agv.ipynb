# %%
# Tratamiento de datos
import numpy as np
import pandas as pd

# Gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# Estadísticas
import scipy.stats as stats
from scipy.stats import f_oneway
from scipy.stats import shapiro
 
# mis cosas
import sys
import os

# %%
data = pd.read_csv('data/com_train.csv') #aquí dejo el original de lectura de datos

data.head(2)
# Out:
#    laptop_ID Company             Product  TypeName  Inches   ScreenResolution  \
# 0       1223    Dell       Inspiron 5567  Notebook    15.6  Full HD 1920x1080
# 1         78  Lenovo  IdeaPad 320-15IKBN  Notebook    15.6  Full HD 1920x1080
#
#                           Cpu  Ram     Memory                    Gpu  \
# 0  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD     AMD Radeon R7 M445
# 1  Intel Core i5 7200U 2.5GHz  8GB    2TB HDD  Intel HD Graphics 620
#
#         OpSys  Weight  Price_euros
# 0  Windows 10  2.36kg        889.0
# 1       No OS   2.2kg        519.0

# %%
df = data.copy()

# %%
df.set_index('laptop_ID', inplace=True)

print(df.shape)
print(df.info())
df.head()
# Out:
# (912, 12)
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 1223 to 531
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_euros       912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB
# None
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook    15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 1267         Dell              XPS 13  2 in 1 Convertible    13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 922            LG         Gram 14Z970           Ultrabook    14.0
#
#                                     ScreenResolution  \
# laptop_ID
# 1223                               Full HD 1920x1080
# 78                                 Full HD 1920x1080
# 1267                Quad HD+ / Touchscreen 3200x1800
# 161                  Full HD / Touchscreen 1920x1080
# 922        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                   Cpu  Ram     Memory                     Gpu  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz  8GB  256GB SSD      AMD Radeon R7 M445
# 78         Intel Core i5 7200U 2.5GHz  8GB    2TB HDD   Intel HD Graphics 620
# 1267        Intel Core i5 7Y54 1.2GHz  8GB  256GB SSD   Intel HD Graphics 615
# 161        Intel Core i7 8550U 1.8GHz  8GB  256GB SSD  Intel UHD Graphics 620
# 922        Intel Core i7 7500U 2.7GHz  8GB  512GB SSD   Intel HD Graphics 620
#
#                 OpSys  Weight  Price_euros
# laptop_ID
# 1223       Windows 10  2.36kg        889.0
# 78              No OS   2.2kg        519.0
# 1267       Windows 10  1.24kg       1813.0
# 161        Windows 10  1.56kg       1049.0
# 922        Windows 10  0.98kg       1899.0

# %% [markdown]
# Voya a convertir los datos posibles en numéricos para trabajar con ellos.

# %%
# primero trabajo en la columna RAM
df["Ram"] = df["Ram"].str.replace("GB", "").astype(int)  # Quita "GB" y convierte a entero

# Renombrar la columna 'Ram' a 'RAM (GB)'
df.rename(columns={"Ram": "RAM (GB)"}, inplace=True)

df.head(1)
# Out:
#           Company        Product  TypeName  Inches   ScreenResolution  \
# laptop_ID
# 1223         Dell  Inspiron 5567  Notebook    15.6  Full HD 1920x1080
#
#                                   Cpu  RAM (GB)     Memory  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz         8  256GB SSD
#
#                           Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1223       AMD Radeon R7 M445  Windows 10  2.36kg        889.0

# %%
# ahora la columna peso 
df["Weight"] = df["Weight"].str.replace("kg", "").astype(float)  # Quita "kg" y convierte a flotante

# Renombrar la columna 'Ram' a 'RAM (GB)'
df.rename(columns={"Weight": "Weight (kg)"}, inplace=True)

df.head()
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook    15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 1267         Dell              XPS 13  2 in 1 Convertible    13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 922            LG         Gram 14Z970           Ultrabook    14.0
#
#                                     ScreenResolution  \
# laptop_ID
# 1223                               Full HD 1920x1080
# 78                                 Full HD 1920x1080
# 1267                Quad HD+ / Touchscreen 3200x1800
# 161                  Full HD / Touchscreen 1920x1080
# 922        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                   Cpu  RAM (GB)     Memory  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz         8  256GB SSD
# 78         Intel Core i5 7200U 2.5GHz         8    2TB HDD
# 1267        Intel Core i5 7Y54 1.2GHz         8  256GB SSD
# 161        Intel Core i7 8550U 1.8GHz         8  256GB SSD
# 922        Intel Core i7 7500U 2.7GHz         8  512GB SSD
#
#                               Gpu       OpSys  Weight (kg)  Price_euros
# laptop_ID
# 1223           AMD Radeon R7 M445  Windows 10         2.36        889.0
# 78          Intel HD Graphics 620       No OS         2.20        519.0
# 1267        Intel HD Graphics 615  Windows 10         1.24       1813.0
# 161        Intel UHD Graphics 620  Windows 10         1.56       1049.0
# 922         Intel HD Graphics 620  Windows 10         0.98       1899.0

# %%
# ahora la columna pulgadas de la pantalla
df["Inches"] = df["Inches"].astype(float)  # convierte a flotante

df.rename(columns={'Inches': 'Inches(")'}, inplace=True)

# %%
df
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
# ...           ...                 ...                 ...        ...
# 709        Lenovo   IdeaPad 320-15AST            Notebook       15.6
# 947        Lenovo      Yoga 900-13ISK  2 in 1 Convertible       13.3
# 590          Dell       Latitude 5580            Notebook       15.6
# 1143       Lenovo  Legion Y520-15IKBN              Gaming       15.6
# 531          Dell       Inspiron 5770            Notebook       17.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1223                                Full HD 1920x1080
# 78                                  Full HD 1920x1080
# 1267                 Quad HD+ / Touchscreen 3200x1800
# 161                   Full HD / Touchscreen 1920x1080
# 922         IPS Panel Full HD / Touchscreen 1920x1080
# ...                                               ...
# 709                                 Full HD 1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen 3200x1800
# 590                                 Full HD 1920x1080
# 1143                      IPS Panel Full HD 1920x1080
# 531                       IPS Panel Full HD 1920x1080
#
#                                    Cpu  RAM (GB)                Memory  \
# laptop_ID
# 1223        Intel Core i5 7200U 2.5GHz         8             256GB SSD
# 78          Intel Core i5 7200U 2.5GHz         8               2TB HDD
# 1267         Intel Core i5 7Y54 1.2GHz         8             256GB SSD
# 161         Intel Core i7 8550U 1.8GHz         8             256GB SSD
# 922         Intel Core i7 7500U 2.7GHz         8             512GB SSD
# ...                                ...       ...                   ...
# 709          AMD A9-Series 9420 2.9GHz         4             256GB SSD
# 947         Intel Core i7 6560U 2.2GHz        16               1TB SSD
# 590         Intel Core i7 7600U 2.8GHz        16             256GB SSD
# 1143       Intel Core i5 7300HQ 2.5GHz         8  128GB SSD +  1TB HDD
# 531         Intel Core i5 8250U 1.6GHz         8  128GB SSD +  1TB HDD
#
#                                Gpu       OpSys  Weight (kg)  Price_euros
# laptop_ID
# 1223            AMD Radeon R7 M445  Windows 10         2.36       889.00
# 78           Intel HD Graphics 620       No OS         2.20       519.00
# 1267         Intel HD Graphics 615  Windows 10         1.24      1813.00
# 161         Intel UHD Graphics 620  Windows 10         1.56      1049.00
# 922          Intel HD Graphics 620  Windows 10         0.98      1899.00
# ...                            ...         ...          ...          ...
# 709                 AMD Radeon 530  Windows 10         2.20       399.00
# 947        Intel Iris Graphics 540  Windows 10         1.30      1799.00
# 590           Nvidia GeForce 930MX  Windows 10         1.93      1537.39
# 1143       Nvidia GeForce GTX 1060       No OS         2.40       989.00
# 531                 AMD Radeon 530       Linux         2.80       889.00
#
# [912 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 1223 to 531
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches(")         912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   RAM (GB)          912 non-null    int64
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight (kg)       912 non-null    float64
#  11  Price_euros       912 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 92.6+ KB

# %% [markdown]
# Voy a hacer una función para convertir en texto todas la columnas que cumplan:

# %%
def object_to_string(df):
    """
    Convierte todas las columnas de tipo 'object' a 'string'
    si no contienen valores nulos.
    """
    for col in df.select_dtypes(include='object').columns:
        if df[col].isna().sum() == 0:  # Verifica que no tenga nulos
            df[col] = df[col].astype("string")
    return df

# %%
df = object_to_string(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 1223 to 531
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    string
#  1   Product           912 non-null    string
#  2   TypeName          912 non-null    string
#  3   Inches(")         912 non-null    float64
#  4   ScreenResolution  912 non-null    string
#  5   Cpu               912 non-null    string
#  6   RAM (GB)          912 non-null    int64
#  7   Memory            912 non-null    string
#  8   Gpu               912 non-null    string
#  9   OpSys             912 non-null    string
#  10  Weight (kg)       912 non-null    float64
#  11  Price_euros       912 non-null    float64
# dtypes: float64(3), int64(1), string(8)
# memory usage: 92.6 KB

# %% [markdown]
# Ahora hacemos las operaciones de dividir columnas en varias para segmentar la información, y así poder trabajar luego con ella.
# Primeramente con la columna de Memory, subdividiendola en dos, con el valor que corresponde en cada caso.

# %%
# Filtrar filas donde no aparezcan ni 'SSD' ni 'HDD'
filtered_df = df[~df['Memory'].str.contains('SSD|HDD|Flash', case=False, na=False)]
filtered_df
# Out:
#           Company                              Product  TypeName  Inches(")  \
# laptop_ID
# 154          Dell                        Inspiron 7567    Gaming       15.6
# 1298           HP                  Pavilion 15-AW003nv  Notebook       15.6
# 1176       Lenovo   B51-80 (i5-6200U/8GB/1008GB/Radeon  Notebook       15.6
# 1284           HP                  Pavilion 15-AW003nv  Notebook       15.6
# 1194       Lenovo  B51-80 (i7-6500U/4GB/1008GB/FHD/W7)  Notebook       15.6
# 1150       Lenovo                    IdeaPad 500-15ISK  Notebook       15.6
# 1312           HP                  Pavilion 15-AW003nv  Notebook       15.6
# 1024         Dell                        Inspiron 7567    Gaming       15.6
#
#             ScreenResolution                          Cpu  RAM (GB)  \
# laptop_ID
# 154        Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz         8
# 1298       Full HD 1920x1080    AMD A9-Series 9410 2.9GHz         6
# 1176       Full HD 1920x1080   Intel Core i5 6200U 2.3GHz         8
# 1284       Full HD 1920x1080    AMD A9-Series 9410 2.9GHz         6
# 1194       Full HD 1920x1080   Intel Core i7 6500U 2.5GHz         4
# 1150       Full HD 1920x1080   Intel Core i7 6500U 2.5GHz        16
# 1312       Full HD 1920x1080    AMD A9-Series 9410 2.9GHz         6
# 1024       Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz         8
#
#                  Memory                      Gpu       OpSys  Weight (kg)  \
# laptop_ID
# 154        1.0TB Hybrid  Nvidia GeForce GTX 1050  Windows 10         2.62
# 1298       1.0TB Hybrid       AMD Radeon R7 M440  Windows 10         2.04
# 1176       1.0TB Hybrid       AMD Radeon R5 M330  Windows 10         2.50
# 1284       1.0TB Hybrid       AMD Radeon R7 M440  Windows 10         2.04
# 1194       1.0TB Hybrid    Intel HD Graphics 520   Windows 7         2.32
# 1150       1.0TB Hybrid       AMD Radeon R7 M360  Windows 10         2.50
# 1312       1.0TB Hybrid       AMD Radeon R7 M440  Windows 10         2.04
# 1024       1.0TB Hybrid  Nvidia GeForce GTX 1050  Windows 10         2.65
#
#            Price_euros
# laptop_ID
# 154             899.00
# 1298            549.99
# 1176            788.49
# 1284            549.99
# 1194            825.00
# 1150           1099.00
# 1312            549.99
# 1024            949.00

# %%
# Función para procesar cada fila
def split_memory(memory):
    # Inicializar los valores de las columnas
    memory_ssd = 0
    memory_hdd = 0
    memory_sshd = 0
    
    # Dividir el string por el separador '+'
    parts = memory.split('+')
    
    # Analizar cada parte
    for part in parts:
        part = part.strip()  # Limpiar espacios en blanco
        if 'SSD' in part or 'Flash' in part:
            memory_ssd = part
        elif 'HDD' in part:
            memory_hdd = part
        elif 'Hybrid' in part:
            memory_sshd = part
    
    return memory_ssd, memory_hdd, memory_sshd

# Aplicar la función a la columna 'Memory'
df[['Memory SSD', 'Memory HDD', 'Memory SSHD']] = df['Memory'].apply(split_memory).apply(pd.Series)

# Convertir valores faltantes o no definidos a '0'
df['Memory SSD'] = df['Memory SSD'].fillna('0')
df['Memory HDD'] = df['Memory HDD'].fillna('0')
df['Memory SSHD'] = df['Memory SSHD'].fillna('0')

# Mover las columnas con insert()
df.insert(8, 'Memory SSD', df.pop('Memory SSD'))
df.insert(9, 'Memory HDD', df.pop('Memory HDD'))
df.insert(10, 'Memory SSHD', df.pop('Memory SSHD'))

# %%
# Función para procesar las columnas
def memory_int (column):
    numeric_values = []
    for value in column:
        if value == '0' or value == 0:  # Si es 0, mantenerlo como está
            numeric_values.append(0)
        else:
            # Extraer el valor numérico
            number = int(''.join(filter(str.isdigit, value)))  # Extraer solo los números
            # Multiplicar por 1000 si contiene TB
            if 'TB' in value:
                number *= 1000
            numeric_values.append(number)
    return numeric_values

# Procesar cada columna y convertir a GB
df['Memory SSD (GB)'] = memory_int (df['Memory SSD'])
df['Memory HDD (GB)'] = memory_int (df['Memory HDD'])
df['Memory SSHD (GB)'] = memory_int (df['Memory SSHD'])

# Mover las columnas con insert()
df.insert(8, 'Memory SSD (GB)', df.pop('Memory SSD (GB)'))
df.insert(9, 'Memory HDD (GB)', df.pop('Memory HDD (GB)'))
df.insert(10, 'Memory SSHD (GB)', df.pop('Memory SSHD (GB)'))

# Eliminar las columnas originales
df = df.drop(columns=['Memory SSD', 'Memory HDD', 'Memory SSHD'])

# Mostrar el resultado
df.head()
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
#
#                                     ScreenResolution  \
# laptop_ID
# 1223                               Full HD 1920x1080
# 78                                 Full HD 1920x1080
# 1267                Quad HD+ / Touchscreen 3200x1800
# 161                  Full HD / Touchscreen 1920x1080
# 922        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                   Cpu  RAM (GB)     Memory  Memory SSD (GB)  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz         8  256GB SSD              256
# 78         Intel Core i5 7200U 2.5GHz         8    2TB HDD                0
# 1267        Intel Core i5 7Y54 1.2GHz         8  256GB SSD              256
# 161        Intel Core i7 8550U 1.8GHz         8  256GB SSD              256
# 922        Intel Core i7 7500U 2.7GHz         8  512GB SSD              512
#
#            Memory HDD (GB)  Memory SSHD (GB)                     Gpu  \
# laptop_ID
# 1223                     0                 0      AMD Radeon R7 M445
# 78                    2000                 0   Intel HD Graphics 620
# 1267                     0                 0   Intel HD Graphics 615
# 161                      0                 0  Intel UHD Graphics 620
# 922                      0                 0   Intel HD Graphics 620
#
#                 OpSys  Weight (kg)  Price_euros
# laptop_ID
# 1223       Windows 10         2.36        889.0
# 78              No OS         2.20        519.0
# 1267       Windows 10         1.24       1813.0
# 161        Windows 10         1.56       1049.0
# 922        Windows 10         0.98       1899.0

# %%
# Extraer la primera palabra de la columna 'Cpu'
df['Cpu_Maker'] = df['Cpu'].str.split().str[0]

# Filtrar una fila por cada valor único en 'Cpu_Maker'
unique_cpu_df = df.drop_duplicates(subset='Cpu_Maker', keep='first')

# Mostrar el resultado
unique_cpu_df
# Out:
#           Company                               Product  TypeName  Inches(")  \
# laptop_ID
# 1223         Dell                         Inspiron 5567  Notebook       15.6
# 1123           HP  15-bw011nv (A6-9220/4GB/1TB/FHD/W10)  Notebook       15.6
#
#             ScreenResolution                         Cpu  RAM (GB)     Memory  \
# laptop_ID
# 1223       Full HD 1920x1080  Intel Core i5 7200U 2.5GHz         8  256GB SSD
# 1123       Full HD 1920x1080   AMD A6-Series 9220 2.5GHz         4    1TB HDD
#
#            Memory SSD (GB)  Memory HDD (GB)  Memory SSHD (GB)  \
# laptop_ID
# 1223                   256                0                 0
# 1123                     0             1000                 0
#
#                           Gpu       OpSys  Weight (kg)  Price_euros Cpu_Maker
# laptop_ID
# 1223       AMD Radeon R7 M445  Windows 10         2.36        889.0     Intel
# 1123            AMD Radeon R4  Windows 10         2.10        398.0       AMD

# %%
# Eliminar las columna que acabo de crear
df = df.drop(columns=['Cpu_Maker'])

# %%
# Lista de valores únicos para 'CPU Maker'
cpu_makers = ['Intel', 'AMD', 'Samsung']

# Extraer 'CPU Maker' y el resto como 'CPU Model'
if 'CPU Maker' not in df.columns:
    df['CPU Maker'] = df['Cpu'].apply(lambda x: next((maker for maker in cpu_makers if maker in x), 'Other'))
if 'CPU Model' not in df.columns:
    df['CPU Model'] = df['Cpu'].str.replace('|'.join(cpu_makers), '', regex=True).str.strip()

# Reorganizar columnas para colocar las nuevas detrás de 'Cpu'
cols = df.columns.tolist()
cpu_idx = cols.index('Cpu')
new_cols_order = cols[:cpu_idx + 1] + ['CPU Maker', 'CPU Model'] + cols[cpu_idx + 1:-2]
df = df[new_cols_order]

df.head()
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
#
#                                     ScreenResolution  \
# laptop_ID
# 1223                               Full HD 1920x1080
# 78                                 Full HD 1920x1080
# 1267                Quad HD+ / Touchscreen 3200x1800
# 161                  Full HD / Touchscreen 1920x1080
# 922        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                   Cpu CPU Maker             CPU Model  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz     Intel  Core i5 7200U 2.5GHz
# 78         Intel Core i5 7200U 2.5GHz     Intel  Core i5 7200U 2.5GHz
# 1267        Intel Core i5 7Y54 1.2GHz     Intel   Core i5 7Y54 1.2GHz
# 161        Intel Core i7 8550U 1.8GHz     Intel  Core i7 8550U 1.8GHz
# 922        Intel Core i7 7500U 2.7GHz     Intel  Core i7 7500U 2.7GHz
#
#            RAM (GB)     Memory  Memory SSD (GB)  Memory HDD (GB)  \
# laptop_ID
# 1223              8  256GB SSD              256                0
# 78                8    2TB HDD                0             2000
# 1267              8  256GB SSD              256                0
# 161               8  256GB SSD              256                0
# 922               8  512GB SSD              512                0
#
#            Memory SSHD (GB)                     Gpu       OpSys  Weight (kg)  \
# laptop_ID
# 1223                      0      AMD Radeon R7 M445  Windows 10         2.36
# 78                        0   Intel HD Graphics 620       No OS         2.20
# 1267                      0   Intel HD Graphics 615  Windows 10         1.24
# 161                       0  Intel UHD Graphics 620  Windows 10         1.56
# 922                       0   Intel HD Graphics 620  Windows 10         0.98
#
#            Price_euros
# laptop_ID
# 1223             889.0
# 78               519.0
# 1267            1813.0
# 161             1049.0
# 922             1899.0

# %%
# Extraer la primera palabra de la columna 'Gpu'
df['Gpu_Maker'] = df['Gpu'].str.split().str[0]

# Filtrar una fila por cada valor único en 'Gpu_Maker'
unique_gpu_df = df.drop_duplicates(subset='Gpu_Maker', keep='first')

# Mostrar el resultado
unique_gpu_df
# Out:
#           Company             Product  TypeName  Inches(")   ScreenResolution  \
# laptop_ID
# 1223         Dell       Inspiron 5567  Notebook       15.6  Full HD 1920x1080
# 78         Lenovo  IdeaPad 320-15IKBN  Notebook       15.6  Full HD 1920x1080
# 993          Asus    Rog GL753VE-DS74    Gaming       17.3  Full HD 1920x1080
#
#                                    Cpu CPU Maker              CPU Model  \
# laptop_ID
# 1223        Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz
# 78          Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz
# 993        Intel Core i7 7700HQ 2.8GHz     Intel  Core i7 7700HQ 2.8GHz
#
#            RAM (GB)                Memory  Memory SSD (GB)  Memory HDD (GB)  \
# laptop_ID
# 1223              8             256GB SSD              256                0
# 78                8               2TB HDD                0             2000
# 993              16  256GB SSD +  1TB HDD              256             1000
#
#            Memory SSHD (GB)                         Gpu       OpSys  \
# laptop_ID
# 1223                      0          AMD Radeon R7 M445  Windows 10
# 78                        0       Intel HD Graphics 620       No OS
# 993                       0  Nvidia GeForce GTX 1050 Ti  Windows 10
#
#            Weight (kg)  Price_euros Gpu_Maker
# laptop_ID
# 1223              2.36        889.0       AMD
# 78                2.20        519.0     Intel
# 993               2.99       1749.0    Nvidia

# %%
# Eliminar las columna que acabo de crear
df = df.drop(columns=['Gpu_Maker'])

# %%
# Lista de valores únicos para 'GPU Maker'
gpu_makers = ['Intel', 'AMD', 'Nvidia', 'ARM']

# Extraer 'GPU Maker' y el resto como 'GPU Model'
if 'GPU Maker' not in df.columns:
    df['GPU Maker'] = df['Gpu'].apply(lambda x: next((maker for maker in gpu_makers if maker in x), 'Other'))
if 'GPU Model' not in df.columns:
    df['GPU Model'] = df['Gpu'].str.replace('|'.join(gpu_makers), '', regex=True).str.strip()

# Reorganizar columnas para colocar las nuevas detrás de 'Gpu'
cols = df.columns.tolist()
gpu_idx = cols.index('Gpu')
new_cols_order = cols[:gpu_idx + 1] + ['GPU Maker', 'GPU Model'] + cols[gpu_idx + 1:-2]
df = df[new_cols_order]

df.head()
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
#
#                                     ScreenResolution  \
# laptop_ID
# 1223                               Full HD 1920x1080
# 78                                 Full HD 1920x1080
# 1267                Quad HD+ / Touchscreen 3200x1800
# 161                  Full HD / Touchscreen 1920x1080
# 922        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                   Cpu CPU Maker             CPU Model  \
# laptop_ID
# 1223       Intel Core i5 7200U 2.5GHz     Intel  Core i5 7200U 2.5GHz
# 78         Intel Core i5 7200U 2.5GHz     Intel  Core i5 7200U 2.5GHz
# 1267        Intel Core i5 7Y54 1.2GHz     Intel   Core i5 7Y54 1.2GHz
# 161        Intel Core i7 8550U 1.8GHz     Intel  Core i7 8550U 1.8GHz
# 922        Intel Core i7 7500U 2.7GHz     Intel  Core i7 7500U 2.7GHz
#
#            RAM (GB)     Memory  Memory SSD (GB)  Memory HDD (GB)  \
# laptop_ID
# 1223              8  256GB SSD              256                0
# 78                8    2TB HDD                0             2000
# 1267              8  256GB SSD              256                0
# 161               8  256GB SSD              256                0
# 922               8  512GB SSD              512                0
#
#            Memory SSHD (GB)                     Gpu GPU Maker  \
# laptop_ID
# 1223                      0      AMD Radeon R7 M445       AMD
# 78                        0   Intel HD Graphics 620     Intel
# 1267                      0   Intel HD Graphics 615     Intel
# 161                       0  Intel UHD Graphics 620     Intel
# 922                       0   Intel HD Graphics 620     Intel
#
#                   GPU Model       OpSys  Weight (kg)  Price_euros
# laptop_ID
# 1223         Radeon R7 M445  Windows 10         2.36        889.0
# 78          HD Graphics 620       No OS         2.20        519.0
# 1267        HD Graphics 615  Windows 10         1.24       1813.0
# 161        UHD Graphics 620  Windows 10         1.56       1049.0
# 922         HD Graphics 620  Windows 10         0.98       1899.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 1223 to 531
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    string
#  1   Product           912 non-null    string
#  2   TypeName          912 non-null    string
#  3   Inches(")         912 non-null    float64
#  4   ScreenResolution  912 non-null    string
#  5   Cpu               912 non-null    string
#  6   CPU Maker         912 non-null    object
#  7   CPU Model         912 non-null    string
#  8   RAM (GB)          912 non-null    int64
#  9   Memory            912 non-null    string
#  10  Memory SSD (GB)   912 non-null    int64
#  11  Memory HDD (GB)   912 non-null    int64
#  12  Memory SSHD (GB)  912 non-null    int64
#  13  Gpu               912 non-null    string
#  14  GPU Maker         912 non-null    object
#  15  GPU Model         912 non-null    string
#  16  OpSys             912 non-null    string
#  17  Weight (kg)       912 non-null    float64
#  18  Price_euros       912 non-null    float64
# dtypes: float64(3), int64(4), object(2), string(10)
# memory usage: 142.5+ KB

# %%
# Filtrar valores únicos de 'OpSys' y convertirlos a un DataFrame
unique_os_df = pd.DataFrame({'OpSys': df['OpSys'].unique()})

unique_os_df
# Out:
#           OpSys
# 0    Windows 10
# 1         No OS
# 2     Chrome OS
# 3         Linux
# 4     Windows 7
# 5      Mac OS X
# 6         macOS
# 7  Windows 10 S
# 8       Android

# %%
df_mac = df[df["OpSys"].str.contains("mac", case=False, na=False)]
df_mac
# Out:
#           Company      Product   TypeName  Inches(")  \
# laptop_ID
# 7           Apple  MacBook Pro  Ultrabook       15.4
# 1228        Apple  MacBook 12"  Ultrabook       12.0
# 46          Apple  MacBook Pro  Ultrabook       13.3
# 18          Apple  MacBook Pro  Ultrabook       15.4
# 1211        Apple  MacBook 12"  Ultrabook       12.0
# 35          Apple  MacBook Air  Ultrabook       13.3
# 275         Apple  MacBook Pro  Ultrabook       13.3
# 15          Apple  MacBook 12"  Ultrabook       12.0
# 254         Apple  MacBook Pro  Ultrabook       13.3
# 2           Apple  Macbook Air  Ultrabook       13.3
# 8           Apple  Macbook Air  Ultrabook       13.3
# 1084        Apple  MacBook 12"  Ultrabook       12.0
# 1           Apple  MacBook Pro  Ultrabook       13.3
# 83          Apple  MacBook 12"  Ultrabook       12.0
# 27          Apple  MacBook Air  Ultrabook       13.3
#
#                              ScreenResolution                     Cpu  \
# laptop_ID
# 7          IPS Panel Retina Display 2880x1800    Intel Core i7 2.2GHz
# 1228       IPS Panel Retina Display 2304x1440     Intel Core M 1.2GHz
# 46         IPS Panel Retina Display 2560x1600    Intel Core i5 2.0GHz
# 18         IPS Panel Retina Display 2880x1800    Intel Core i7 2.9GHz
# 1211       IPS Panel Retina Display 2304x1440     Intel Core M 1.1GHz
# 35                                   1440x900    Intel Core i5 1.6GHz
# 275        IPS Panel Retina Display 2560x1600    Intel Core i5 2.9GHz
# 15         IPS Panel Retina Display 2304x1440  Intel Core M m3 1.2GHz
# 254        IPS Panel Retina Display 2560x1600    Intel Core i5 3.1GHz
# 2                                    1440x900    Intel Core i5 1.8GHz
# 8                                    1440x900    Intel Core i5 1.8GHz
# 1084       IPS Panel Retina Display 2304x1440     Intel Core M 1.1GHz
# 1          IPS Panel Retina Display 2560x1600    Intel Core i5 2.3GHz
# 83         IPS Panel Retina Display 2304x1440    Intel Core i5 1.3GHz
# 27                                   1440x900    Intel Core i5 1.6GHz
#
#           CPU Maker         CPU Model  RAM (GB)               Memory  \
# laptop_ID
# 7             Intel    Core i7 2.2GHz        16  256GB Flash Storage
# 1228          Intel     Core M 1.2GHz         8  512GB Flash Storage
# 46            Intel    Core i5 2.0GHz         8            256GB SSD
# 18            Intel    Core i7 2.9GHz        16            512GB SSD
# 1211          Intel     Core M 1.1GHz         8  256GB Flash Storage
# 35            Intel    Core i5 1.6GHz         8  256GB Flash Storage
# 275           Intel    Core i5 2.9GHz         8            512GB SSD
# 15            Intel  Core M m3 1.2GHz         8            256GB SSD
# 254           Intel    Core i5 3.1GHz         8            512GB SSD
# 2             Intel    Core i5 1.8GHz         8  128GB Flash Storage
# 8             Intel    Core i5 1.8GHz         8  256GB Flash Storage
# 1084          Intel     Core M 1.1GHz         8  256GB Flash Storage
# 1             Intel    Core i5 2.3GHz         8            128GB SSD
# 83            Intel    Core i5 1.3GHz         8            512GB SSD
# 27            Intel    Core i5 1.6GHz         8  128GB Flash Storage
#
#            Memory SSD (GB)  Memory HDD (GB)  Memory SSHD (GB)  \
# laptop_ID
# 7                      256                0                 0
# 1228                   512                0                 0
# 46                     256                0                 0
# 18                     512                0                 0
# 1211                   256                0                 0
# 35                     256                0                 0
# 275                    512                0                 0
# 15                     256                0                 0
# 254                    512                0                 0
# 2                      128                0                 0
# 8                      256                0                 0
# 1084                   256                0                 0
# 1                      128                0                 0
# 83                     512                0                 0
# 27                     128                0                 0
#
#                                     Gpu GPU Maker               GPU Model  \
# laptop_ID
# 7               Intel Iris Pro Graphics     Intel       Iris Pro Graphics
# 1228              Intel HD Graphics 515     Intel         HD Graphics 515
# 46              Intel Iris Graphics 540     Intel       Iris Graphics 540
# 18                   AMD Radeon Pro 560       AMD          Radeon Pro 560
# 1211             Intel HD Graphics 5300     Intel        HD Graphics 5300
# 35               Intel HD Graphics 6000     Intel        HD Graphics 6000
# 275             Intel Iris Graphics 550     Intel       Iris Graphics 550
# 15                Intel HD Graphics 615     Intel         HD Graphics 615
# 254        Intel Iris Plus Graphics 650     Intel  Iris Plus Graphics 650
# 2                Intel HD Graphics 6000     Intel        HD Graphics 6000
# 8                Intel HD Graphics 6000     Intel        HD Graphics 6000
# 1084              Intel HD Graphics 515     Intel         HD Graphics 515
# 1          Intel Iris Plus Graphics 640     Intel  Iris Plus Graphics 640
# 83                Intel HD Graphics 615     Intel         HD Graphics 615
# 27               Intel HD Graphics 6000     Intel        HD Graphics 6000
#
#               OpSys  Weight (kg)  Price_euros
# laptop_ID
# 7          Mac OS X         2.04      2139.97
# 1228       Mac OS X         0.92      1279.00
# 46            macOS         1.37      1419.00
# 18            macOS         1.83      2858.00
# 1211       Mac OS X         0.92      1163.00
# 35         Mac OS X         1.35       998.00
# 275           macOS         1.37      1958.90
# 15            macOS         0.92      1262.40
# 254           macOS         1.37      2040.00
# 2             macOS         1.34       898.94
# 8             macOS         1.34      1158.70
# 1084       Mac OS X         0.92      1300.00
# 1             macOS         1.37      1339.69
# 83            macOS         0.92      1510.00
# 27         Mac OS X         1.35      1099.00

# %% [markdown]
# Voy a estandarizar los nombres de los sistemas operativos, y despues segregar la columna en fabricante y versión

# %%
# Diccionario de normalización
mapeo_sistemas = {
    "Windows 10": ("Windows", "10"),
    "Windows 10 S": ("Windows", "10 S"),
    "Windows 7": ("Windows", "7"),
    "Mac OS X": ("Mac", "X"),
    "macOS": ("Mac", "0"),
    "Linux": ("Linux", "0"),
    "Chrome OS": ("Chrome", "0"),
    "No OS": ("0", "No OS"),
    "Android": ("Android", "0")
}

# Función para mapear fabricante y versión
def obtener_fabricante_version(op):
    return mapeo_sistemas.get(op, ("Desconocido", "Desconocido"))

# Aplicar la función a la columna OpSys
df[["OS_Maker", "OS_Version"]] = df["OpSys"].apply(lambda x: pd.Series(obtener_fabricante_version(x)))

# Reemplazar la columna original con valores normalizados
df["OpSys"] = df["OpSys"].replace(mapeo_sistemas.keys(), mapeo_sistemas.keys())  # Mantiene la info original

# Mostrar resultado
print(df[["OpSys", "OS_Maker", "OS_Version"]])
# Out:
#                 OpSys OS_Maker OS_Version
# laptop_ID
# 1223       Windows 10  Windows         10
# 78              No OS        0      No OS
# 1267       Windows 10  Windows         10
# 161        Windows 10  Windows         10
# 922        Windows 10  Windows         10
# ...               ...      ...        ...
# 709        Windows 10  Windows         10
# 947        Windows 10  Windows         10
# 590        Windows 10  Windows         10
# 1143            No OS        0      No OS
# 531             Linux    Linux          0
#
# [912 rows x 3 columns]

# %%
# Reordenar las columnas para que 'OS_Maker' y 'OS_Version' estén después de 'OpSys'
columnas = df.columns.tolist()  # Obtener todas las columnas
indice_opsys = columnas.index("OpSys")  # Encontrar la posición de 'OpSys'
columnas.insert(indice_opsys + 1, columnas.pop(columnas.index("OS_Maker")))  # Insertar 'OS_Maker' después de 'OpSys'
columnas.insert(indice_opsys + 2, columnas.pop(columnas.index("OS_Version")))  # Insertar 'OS_Version' después de 'OS_Maker'

df = df[columnas]  # Reorganizar el DataFrame con el nuevo orden

df.head()
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
# ...           ...                 ...                 ...        ...
# 709        Lenovo   IdeaPad 320-15AST            Notebook       15.6
# 947        Lenovo      Yoga 900-13ISK  2 in 1 Convertible       13.3
# 590          Dell       Latitude 5580            Notebook       15.6
# 1143       Lenovo  Legion Y520-15IKBN              Gaming       15.6
# 531          Dell       Inspiron 5770            Notebook       17.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1223                                Full HD 1920x1080
# 78                                  Full HD 1920x1080
# 1267                 Quad HD+ / Touchscreen 3200x1800
# 161                   Full HD / Touchscreen 1920x1080
# 922         IPS Panel Full HD / Touchscreen 1920x1080
# ...                                               ...
# 709                                 Full HD 1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen 3200x1800
# 590                                 Full HD 1920x1080
# 1143                      IPS Panel Full HD 1920x1080
# 531                       IPS Panel Full HD 1920x1080
#
#                                    Cpu CPU Maker              CPU Model  \
# laptop_ID
# 1223        Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz
# 78          Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz
# 1267         Intel Core i5 7Y54 1.2GHz     Intel    Core i5 7Y54 1.2GHz
# 161         Intel Core i7 8550U 1.8GHz     Intel   Core i7 8550U 1.8GHz
# 922         Intel Core i7 7500U 2.7GHz     Intel   Core i7 7500U 2.7GHz
# ...                                ...       ...                    ...
# 709          AMD A9-Series 9420 2.9GHz       AMD  A9-Series 9420 2.9GHz
# 947         Intel Core i7 6560U 2.2GHz     Intel   Core i7 6560U 2.2GHz
# 590         Intel Core i7 7600U 2.8GHz     Intel   Core i7 7600U 2.8GHz
# 1143       Intel Core i5 7300HQ 2.5GHz     Intel  Core i5 7300HQ 2.5GHz
# 531         Intel Core i5 8250U 1.6GHz     Intel   Core i5 8250U 1.6GHz
#
#            RAM (GB)                Memory  ...  Memory HDD (GB)  \
# laptop_ID                                  ...
# 1223              8             256GB SSD  ...                0
# 78                8               2TB HDD  ...             2000
# 1267              8             256GB SSD  ...                0
# 161               8             256GB SSD  ...                0
# 922               8             512GB SSD  ...                0
# ...             ...                   ...  ...              ...
# 709               4             256GB SSD  ...                0
# 947              16               1TB SSD  ...                0
# 590              16             256GB SSD  ...                0
# 1143              8  128GB SSD +  1TB HDD  ...             1000
# 531               8  128GB SSD +  1TB HDD  ...             1000
#
#            Memory SSHD (GB)                      Gpu GPU Maker  \
# laptop_ID
# 1223                      0       AMD Radeon R7 M445       AMD
# 78                        0    Intel HD Graphics 620     Intel
# 1267                      0    Intel HD Graphics 615     Intel
# 161                       0   Intel UHD Graphics 620     Intel
# 922                       0    Intel HD Graphics 620     Intel
# ...                     ...                      ...       ...
# 709                       0           AMD Radeon 530       AMD
# 947                       0  Intel Iris Graphics 540     Intel
# 590                       0     Nvidia GeForce 930MX    Nvidia
# 1143                      0  Nvidia GeForce GTX 1060    Nvidia
# 531                       0           AMD Radeon 530       AMD
#
#                    GPU Model       OpSys OS_Maker OS_Version Weight (kg)  \
# laptop_ID
# 1223          Radeon R7 M445  Windows 10  Windows         10        2.36
# 78           HD Graphics 620       No OS        0      No OS        2.20
# 1267         HD Graphics 615  Windows 10  Windows         10        1.24
# 161         UHD Graphics 620  Windows 10  Windows         10        1.56
# 922          HD Graphics 620  Windows 10  Windows         10        0.98
# ...                      ...         ...      ...        ...         ...
# 709               Radeon 530  Windows 10  Windows         10        2.20
# 947        Iris Graphics 540  Windows 10  Windows         10        1.30
# 590            GeForce 930MX  Windows 10  Windows         10        1.93
# 1143        GeForce GTX 1060       No OS        0      No OS        2.40
# 531               Radeon 530       Linux    Linux          0        2.80
#
#            Price_euros
# laptop_ID
# 1223            889.00
# 78              519.00
# 1267           1813.00
# 161            1049.00
# 922            1899.00
# ...                ...
# 709             399.00
# 947            1799.00
# 590            1537.39
# 1143            989.00
# 531             889.00
#
# [912 rows x 21 columns]

# %%
df['ScreenResolution']
# Out:
# laptop_ID
# 1223                             Full HD 1920x1080
# 78                               Full HD 1920x1080
# 1267              Quad HD+ / Touchscreen 3200x1800
# 161                Full HD / Touchscreen 1920x1080
# 922      IPS Panel Full HD / Touchscreen 1920x1080
#                            ...
# 709                              Full HD 1920x1080
# 947     IPS Panel Quad HD+ / Touchscreen 3200x1800
# 590                              Full HD 1920x1080
# 1143                   IPS Panel Full HD 1920x1080
# 531                    IPS Panel Full HD 1920x1080
# Name: ScreenResolution, Length: 912, dtype: string

# %%
# Función para dividir el tipo de pantalla y la resolución
def separar_screen_resolution(sr):
    partes = sr.rsplit(' ', 1)  # Divide solo en el último espacio
    if len(partes) == 2 and 'x' in partes [1]:  
        return partes[0], partes[1]  # Tipo de pantalla y resolución
    return "Standard (TN)", partes[0]  # Si no hay tipo de pantalla, asignar "Standard"

# Aplicar la función y crear las nuevas columnas
df[["ScreenType", "Resolution"]] = df["ScreenResolution"].apply(lambda x: pd.Series(separar_screen_resolution(x)))
# Out:
# /var/folders/lh/mx1_xdkx76s1jt00m2qwl2km0000gn/T/ipykernel_40926/1572084038.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["ScreenType", "Resolution"]] = df["ScreenResolution"].apply(lambda x: pd.Series(separar_screen_resolution(x)))
# /var/folders/lh/mx1_xdkx76s1jt00m2qwl2km0000gn/T/ipykernel_40926/1572084038.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["ScreenType", "Resolution"]] = df["ScreenResolution"].apply(lambda x: pd.Series(separar_screen_resolution(x)))

# %%
# Reordenar las columnas para que estén después de ScreenResolution
columnas = df.columns.tolist()  # Obtener todas las columnas
indice_screen = columnas.index("ScreenResolution")  # Encontrar la posición de 'ScreenResolution'
columnas.insert(indice_screen + 1, columnas.pop(columnas.index("ScreenType"))) 
columnas.insert(indice_screen + 2, columnas.pop(columnas.index("Resolution")))  

df.drop (columns ='ScreenResolution')
df = df[columnas]  # Reorganizar el DataFrame con el nuevo orden

df
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
# ...           ...                 ...                 ...        ...
# 709        Lenovo   IdeaPad 320-15AST            Notebook       15.6
# 947        Lenovo      Yoga 900-13ISK  2 in 1 Convertible       13.3
# 590          Dell       Latitude 5580            Notebook       15.6
# 1143       Lenovo  Legion Y520-15IKBN              Gaming       15.6
# 531          Dell       Inspiron 5770            Notebook       17.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1223                                Full HD 1920x1080
# 78                                  Full HD 1920x1080
# 1267                 Quad HD+ / Touchscreen 3200x1800
# 161                   Full HD / Touchscreen 1920x1080
# 922         IPS Panel Full HD / Touchscreen 1920x1080
# ...                                               ...
# 709                                 Full HD 1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen 3200x1800
# 590                                 Full HD 1920x1080
# 1143                      IPS Panel Full HD 1920x1080
# 531                       IPS Panel Full HD 1920x1080
#
#                                  ScreenType Resolution  \
# laptop_ID
# 1223                                Full HD  1920x1080
# 78                                  Full HD  1920x1080
# 1267                 Quad HD+ / Touchscreen  3200x1800
# 161                   Full HD / Touchscreen  1920x1080
# 922         IPS Panel Full HD / Touchscreen  1920x1080
# ...                                     ...        ...
# 709                                 Full HD  1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen  3200x1800
# 590                                 Full HD  1920x1080
# 1143                      IPS Panel Full HD  1920x1080
# 531                       IPS Panel Full HD  1920x1080
#
#                                    Cpu CPU Maker              CPU Model  ...  \
# laptop_ID                                                                ...
# 1223        Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz  ...
# 78          Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz  ...
# 1267         Intel Core i5 7Y54 1.2GHz     Intel    Core i5 7Y54 1.2GHz  ...
# 161         Intel Core i7 8550U 1.8GHz     Intel   Core i7 8550U 1.8GHz  ...
# 922         Intel Core i7 7500U 2.7GHz     Intel   Core i7 7500U 2.7GHz  ...
# ...                                ...       ...                    ...  ...
# 709          AMD A9-Series 9420 2.9GHz       AMD  A9-Series 9420 2.9GHz  ...
# 947         Intel Core i7 6560U 2.2GHz     Intel   Core i7 6560U 2.2GHz  ...
# 590         Intel Core i7 7600U 2.8GHz     Intel   Core i7 7600U 2.8GHz  ...
# 1143       Intel Core i5 7300HQ 2.5GHz     Intel  Core i5 7300HQ 2.5GHz  ...
# 531         Intel Core i5 8250U 1.6GHz     Intel   Core i5 8250U 1.6GHz  ...
#
#            Memory HDD (GB) Memory SSHD (GB)                      Gpu  \
# laptop_ID
# 1223                     0                0       AMD Radeon R7 M445
# 78                    2000                0    Intel HD Graphics 620
# 1267                     0                0    Intel HD Graphics 615
# 161                      0                0   Intel UHD Graphics 620
# 922                      0                0    Intel HD Graphics 620
# ...                    ...              ...                      ...
# 709                      0                0           AMD Radeon 530
# 947                      0                0  Intel Iris Graphics 540
# 590                      0                0     Nvidia GeForce 930MX
# 1143                  1000                0  Nvidia GeForce GTX 1060
# 531                   1000                0           AMD Radeon 530
#
#            GPU Maker          GPU Model       OpSys OS_Maker OS_Version  \
# laptop_ID
# 1223             AMD     Radeon R7 M445  Windows 10  Windows         10
# 78             Intel    HD Graphics 620       No OS        0      No OS
# 1267           Intel    HD Graphics 615  Windows 10  Windows         10
# 161            Intel   UHD Graphics 620  Windows 10  Windows         10
# 922            Intel    HD Graphics 620  Windows 10  Windows         10
# ...              ...                ...         ...      ...        ...
# 709              AMD         Radeon 530  Windows 10  Windows         10
# 947            Intel  Iris Graphics 540  Windows 10  Windows         10
# 590           Nvidia      GeForce 930MX  Windows 10  Windows         10
# 1143          Nvidia   GeForce GTX 1060       No OS        0      No OS
# 531              AMD         Radeon 530       Linux    Linux          0
#
#           Weight (kg) Price_euros
# laptop_ID
# 1223             2.36      889.00
# 78               2.20      519.00
# 1267             1.24     1813.00
# 161              1.56     1049.00
# 922              0.98     1899.00
# ...               ...         ...
# 709              2.20      399.00
# 947              1.30     1799.00
# 590              1.93     1537.39
# 1143             2.40      989.00
# 531              2.80      889.00
#
# [912 rows x 23 columns]

# %% [markdown]
# ## Análisis univariado

# %%
df.columns.tolist()
# Out:
# ['Company',
#  'Product',
#  'TypeName',
#  'Inches(")',
#  'ScreenResolution',
#  'ScreenType',
#  'Resolution',
#  'Cpu',
#  'CPU Maker',
#  'CPU Model',
#  'RAM (GB)',
#  'Memory',
#  'Memory SSD (GB)',
#  'Memory HDD (GB)',
#  'Memory SSHD (GB)',
#  'Gpu',
#  'GPU Maker',
#  'GPU Model',
#  'OpSys',
#  'OS_Maker',
#  'OS_Version',
#  'Weight (kg)',
#  'Price_euros']

# %%
# # Seleccionar solo las columnas numéricas
# df_numericas = df.select_dtypes(include=['number'])

# # Generar el pairplot
# sns.pairplot(df_numericas, diag_kind="kde")  
# plt.show()

# %% [markdown]
# _______________________________

# %%
df
# Out:
#           Company             Product            TypeName  Inches(")  \
# laptop_ID
# 1223         Dell       Inspiron 5567            Notebook       15.6
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook       15.6
# 1267         Dell              XPS 13  2 in 1 Convertible       13.3
# 161          Dell       Inspiron 5579  2 in 1 Convertible       15.6
# 922            LG         Gram 14Z970           Ultrabook       14.0
# ...           ...                 ...                 ...        ...
# 709        Lenovo   IdeaPad 320-15AST            Notebook       15.6
# 947        Lenovo      Yoga 900-13ISK  2 in 1 Convertible       13.3
# 590          Dell       Latitude 5580            Notebook       15.6
# 1143       Lenovo  Legion Y520-15IKBN              Gaming       15.6
# 531          Dell       Inspiron 5770            Notebook       17.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1223                                Full HD 1920x1080
# 78                                  Full HD 1920x1080
# 1267                 Quad HD+ / Touchscreen 3200x1800
# 161                   Full HD / Touchscreen 1920x1080
# 922         IPS Panel Full HD / Touchscreen 1920x1080
# ...                                               ...
# 709                                 Full HD 1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen 3200x1800
# 590                                 Full HD 1920x1080
# 1143                      IPS Panel Full HD 1920x1080
# 531                       IPS Panel Full HD 1920x1080
#
#                                  ScreenType Resolution  \
# laptop_ID
# 1223                                Full HD  1920x1080
# 78                                  Full HD  1920x1080
# 1267                 Quad HD+ / Touchscreen  3200x1800
# 161                   Full HD / Touchscreen  1920x1080
# 922         IPS Panel Full HD / Touchscreen  1920x1080
# ...                                     ...        ...
# 709                                 Full HD  1920x1080
# 947        IPS Panel Quad HD+ / Touchscreen  3200x1800
# 590                                 Full HD  1920x1080
# 1143                      IPS Panel Full HD  1920x1080
# 531                       IPS Panel Full HD  1920x1080
#
#                                    Cpu CPU Maker              CPU Model  ...  \
# laptop_ID                                                                ...
# 1223        Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz  ...
# 78          Intel Core i5 7200U 2.5GHz     Intel   Core i5 7200U 2.5GHz  ...
# 1267         Intel Core i5 7Y54 1.2GHz     Intel    Core i5 7Y54 1.2GHz  ...
# 161         Intel Core i7 8550U 1.8GHz     Intel   Core i7 8550U 1.8GHz  ...
# 922         Intel Core i7 7500U 2.7GHz     Intel   Core i7 7500U 2.7GHz  ...
# ...                                ...       ...                    ...  ...
# 709          AMD A9-Series 9420 2.9GHz       AMD  A9-Series 9420 2.9GHz  ...
# 947         Intel Core i7 6560U 2.2GHz     Intel   Core i7 6560U 2.2GHz  ...
# 590         Intel Core i7 7600U 2.8GHz     Intel   Core i7 7600U 2.8GHz  ...
# 1143       Intel Core i5 7300HQ 2.5GHz     Intel  Core i5 7300HQ 2.5GHz  ...
# 531         Intel Core i5 8250U 1.6GHz     Intel   Core i5 8250U 1.6GHz  ...
#
#            Memory HDD (GB) Memory SSHD (GB)                      Gpu  \
# laptop_ID
# 1223                     0                0       AMD Radeon R7 M445
# 78                    2000                0    Intel HD Graphics 620
# 1267                     0                0    Intel HD Graphics 615
# 161                      0                0   Intel UHD Graphics 620
# 922                      0                0    Intel HD Graphics 620
# ...                    ...              ...                      ...
# 709                      0                0           AMD Radeon 530
# 947                      0                0  Intel Iris Graphics 540
# 590                      0                0     Nvidia GeForce 930MX
# 1143                  1000                0  Nvidia GeForce GTX 1060
# 531                   1000                0           AMD Radeon 530
#
#            GPU Maker          GPU Model       OpSys OS_Maker OS_Version  \
# laptop_ID
# 1223             AMD     Radeon R7 M445  Windows 10  Windows         10
# 78             Intel    HD Graphics 620       No OS        0      No OS
# 1267           Intel    HD Graphics 615  Windows 10  Windows         10
# 161            Intel   UHD Graphics 620  Windows 10  Windows         10
# 922            Intel    HD Graphics 620  Windows 10  Windows         10
# ...              ...                ...         ...      ...        ...
# 709              AMD         Radeon 530  Windows 10  Windows         10
# 947            Intel  Iris Graphics 540  Windows 10  Windows         10
# 590           Nvidia      GeForce 930MX  Windows 10  Windows         10
# 1143          Nvidia   GeForce GTX 1060       No OS        0      No OS
# 531              AMD         Radeon 530       Linux    Linux          0
#
#           Weight (kg) Price_euros
# laptop_ID
# 1223             2.36      889.00
# 78               2.20      519.00
# 1267             1.24     1813.00
# 161              1.56     1049.00
# 922              0.98     1899.00
# ...               ...         ...
# 709              2.20      399.00
# 947              1.30     1799.00
# 590              1.93     1537.39
# 1143             2.40      989.00
# 531              2.80      889.00
#
# [912 rows x 23 columns]

# %%
train = df[['RAM (GB)','Memory SSD (GB)','Memory HDD (GB)','Memory SSHD (GB)','Price_euros']]

# %%
X = train.drop(['Price_euros'], axis=1)
y = train['Price_euros'].copy()
X.shape
# Out:
# (912, 4)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# Asignar el modelo (vacío) a una variable

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Sacar métricas, evaluaremos con rmse

# %%
from sklearn.metrics import root_mean_squared_error

predictions = regressor.predict(X)

rmse = root_mean_squared_error(y, predictions)

# %%
print(rmse)
# Out:
# 423.1243804405538

# %% [markdown]
# #### Una vez listo el modelo, toca predecir con el dataset de predicción

# %%
X_pred = pd.read_csv("data/com_test.csv")
X_pred.head()
# Out:
#    laptop_ID   Company                 Product   TypeName  Inches  \
# 0        539      Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 1        327      Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 2        563  Mediacom           SmartBook 130   Notebook    13.3
# 3         13     Apple             MacBook Pro  Ultrabook    15.4
# 4        935        HP           EliteBook 850  Ultrabook    15.6
#
#                      ScreenResolution                          Cpu   Ram  \
# 0     IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz   8GB
# 1                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2         IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz   4GB
# 3  IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 4                   Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
#
#                  Memory                      Gpu       OpSys  Weight
# 0  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2kg
# 1             256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 2    32GB Flash Storage        Intel HD Graphics  Windows 10  1.35kg
# 3             256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 4             256GB SSD      AMD Radeon R7 M365X  Windows 10  1.84kg

# %%
X_pred.shape
# Out:
# (391, 12)

# %% [markdown]
# Aplico en test lo mismo que hice en train.

# %%
df = X_pred.copy()

df.set_index('laptop_ID', inplace=True)

# Voy a a convertir los datos posibles en numéricos para trabajar con ellos. 
# primero trabajo en la columna RAM
df["Ram"] = df["Ram"].str.replace("GB", "").astype(int)  # Quita "GB" y convierte a entero

# Renombrar la columna 'Ram' a 'RAM (GB)'
df.rename(columns={"Ram": "RAM (GB)"}, inplace=True)

df.head()
# Out:
#             Company                 Product   TypeName  Inches  \
# laptop_ID
# 539            Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 327            Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 563        Mediacom           SmartBook 130   Notebook    13.3
# 13            Apple             MacBook Pro  Ultrabook    15.4
# 935              HP           EliteBook 850  Ultrabook    15.6
#
#                              ScreenResolution                          Cpu  \
# laptop_ID
# 539           IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz
# 327                         Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 563               IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz
# 13         IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz
# 935                         Full HD 1920x1080   Intel Core i7 6500U 2.5GHz
#
#            RAM (GB)                Memory                      Gpu  \
# laptop_ID
# 539               8  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M
# 327               8             256GB SSD    Intel HD Graphics 620
# 563               4    32GB Flash Storage        Intel HD Graphics
# 13               16             256GB SSD       AMD Radeon Pro 555
# 935               8             256GB SSD      AMD Radeon R7 M365X
#
#                 OpSys  Weight
# laptop_ID
# 539        Windows 10     2kg
# 327        Windows 10     2kg
# 563        Windows 10  1.35kg
# 13              macOS  1.83kg
# 935        Windows 10  1.84kg

# %%
# Función para procesar cada fila
def split_memory(memory):
    # Inicializar los valores de las columnas
    memory_ssd = 0
    memory_hdd = 0
    memory_sshd = 0
    
    # Dividir el string por el separador '+'
    parts = memory.split('+')
    
    # Analizar cada parte
    for part in parts:
        part = part.strip()  # Limpiar espacios en blanco
        if 'SSD' in part or 'Flash' in part:
            memory_ssd = part
        elif 'HDD' in part:
            memory_hdd = part
        elif 'Hybrid' in part:
            memory_sshd = part
    
    return memory_ssd, memory_hdd, memory_sshd

# Aplicar la función a la columna 'Memory'
df[['Memory SSD', 'Memory HDD', 'Memory SSHD']] = df['Memory'].apply(split_memory).apply(pd.Series)

# Convertir valores faltantes o no definidos a '0'
df['Memory SSD'] = df['Memory SSD'].fillna('0')
df['Memory HDD'] = df['Memory HDD'].fillna('0')
df['Memory SSHD'] = df['Memory SSHD'].fillna('0')

# Mover las columnas con insert()
df.insert(8, 'Memory SSD', df.pop('Memory SSD'))
df.insert(9, 'Memory HDD', df.pop('Memory HDD'))
df.insert(10, 'Memory SSHD', df.pop('Memory SSHD'))


# Función para procesar las columnas
def memory_int (column):
    numeric_values = []
    for value in column:
        if value == '0' or value == 0:  # Si es 0, mantenerlo como está
            numeric_values.append(0)
        else:
            # Extraer el valor numérico
            number = int(''.join(filter(str.isdigit, value)))  # Extraer solo los números
            # Multiplicar por 1000 si contiene TB
            if 'TB' in value:
                number *= 1000
            numeric_values.append(number)
    return numeric_values

# Procesar cada columna y convertir a GB
df['Memory SSD (GB)'] = memory_int (df['Memory SSD'])
df['Memory HDD (GB)'] = memory_int (df['Memory HDD'])
df['Memory SSHD (GB)'] = memory_int (df['Memory SSHD'])

# Mover las columnas con insert()
df.insert(8, 'Memory SSD (GB)', df.pop('Memory SSD (GB)'))
df.insert(9, 'Memory HDD (GB)', df.pop('Memory HDD (GB)'))
df.insert(10, 'Memory SSHD (GB)', df.pop('Memory SSHD (GB)'))

# Eliminar las columnas originales
df = df.drop(columns=['Memory SSD', 'Memory HDD', 'Memory SSHD'])

# %%
X_pred = df[['RAM (GB)','Memory SSD (GB)','Memory HDD (GB)','Memory SSHD (GB)']]

# %% [markdown]
# Ahora hago la predicción, que es lo que subo a Kaggle

# %%
predictions_submit = regressor.predict(X_pred)
predictions_submit
# Out:
# array([1190.42698644, 1184.88231726,  586.05159189, 1730.22030126,
#        1184.88231726,  542.22939314, 1735.76497044,  681.33622374,
#        1557.63858396,  542.22939314, 1184.88231726, 2813.54320136,
#         545.00172774,  542.22939314, 1004.04885309, 1549.38683709,
#         449.71709589, 1004.04885309, 1735.76497044,  545.00172774,
#        1090.33971174, 1184.88231726, 2102.97656796,  542.22939314,
#         725.8351919 ,  731.37986109,  823.21538892, 1735.76497044,
#        1184.88231726, 1004.04885309, 2102.97656796, 1184.88231726,
#         545.00172774, 2102.97656796, 1004.04885309,  586.05159189,
#        1004.04885309, 1735.76497044,  817.67071974, 1184.88231726,
#        1184.88231726, 1184.88231726, 1184.88231726, 1190.42698644,
#         817.67071974,  817.67071974,  912.21332525, 3904.21916936,
#         817.67071974,  725.8351919 ,  545.00172774,  817.67071974,
#         912.21332525,  545.00172774, 1184.88231726,  449.71709589,
#        1004.04885309, 1187.65465185, 2108.52123714, 1184.88231726,
#         817.67071974,  725.8351919 , 1184.88231726,  545.00172774,
#         586.05159189, 2108.52123714,  542.22939314, 1557.63858396,
#        1004.04885309,  912.21332525,  632.64612523, 1184.88231726,
#        1190.42698644,  542.22939314,  545.00172774, 2108.52123714,
#        1184.88231726,  817.67071974, 1090.33971174, 1184.88231726,
#        2102.97656796, 1184.88231726, 2108.52123714,  545.00172774,
#         817.67071974, 1184.88231726, 1549.38683709, 1184.88231726,
#         545.00172774, 1190.42698644,  912.21332525,  725.8351919 ,
#        1549.38683709, 2102.97656796,  817.67071974, 1190.42698644,
#        1557.63858396,  817.67071974, 1730.22030126,  542.22939314,
#        1004.04885309,  725.8351919 , 1549.38683709,  681.33622374,
#         681.33622374,  545.00172774, 1004.04885309, 1004.04885309,
#        1184.88231726,  725.8351919 , 1363.00870374,  912.21332525,
#        1184.88231726, 1735.76497044, 1190.42698644,  542.22939314,
#        2102.97656796,  817.67071974, 1184.88231726,  545.00172774,
#        1735.76497044, 1184.88231726, 1735.76497044,  725.8351919 ,
#        1184.88231726,  725.8351919 , 1557.63858396,  725.8351919 ,
#         542.22939314,  817.67071974,  912.21332525,  545.00172774,
#        1184.88231726, 1184.88231726, 1184.88231726,  817.67071974,
#         867.71435709, 1549.38683709, 1184.88231726, 1184.88231726,
#         725.8351919 , 1184.88231726,  725.8351919 ,  586.05159189,
#         725.8351919 ,  817.67071974, 1184.88231726,  867.71435709,
#         545.00172774,  545.00172774, 1184.88231726, 2648.31455196,
#        2102.97656796, 1184.88231726, 1095.88438092, 1735.76497044,
#        1557.63858396, 2102.97656796,  545.00172774,  542.22939314,
#        1184.88231726, 1184.88231726, 1184.88231726, 2102.97656796,
#         542.22939314,  817.67071974, 1184.88231726, 1184.88231726,
#        1004.04885309, 1195.97165562, 1549.38683709, 1184.88231726,
#        1735.76497044, 1184.88231726, 1363.00870374, 1735.76497044,
#        2114.06590632,  801.55130858, 1184.88231726, 1004.04885309,
#        1735.76497044, 1184.88231726, 1557.63858396,  998.5041839 ,
#        1549.38683709, 1048.54782125, 1730.22030126, 1184.88231726,
#        1184.88231726, 1557.63858396, 1557.63858396, 2102.97656796,
#        1741.30963962, 1184.88231726, 3199.19720514, 1184.88231726,
#         905.31511723,  867.57274238, 1276.71784509, 1184.88231726,
#        1735.76497044,  817.67071974, 1004.04885309, 2813.54320136,
#         912.21332525,  817.67071974, 2102.97656796,  545.00172774,
#        2102.97656796,  912.21332525, 1184.88231726,  817.67071974,
#        2826.44093844, 2102.97656796,  545.00172774,  817.67071974,
#        1730.22030126,  545.00172774,  542.22939314, 1557.63858396,
#         545.00172774, 1735.76497044, 1730.22030126, 1184.88231726,
#         817.67071974, 1004.04885309, 1184.88231726, 1184.88231726,
#        1549.38683709,  814.89838515, 1184.88231726, 1184.88231726,
#        1184.88231726,  817.67071974, 2102.97656796, 1184.88231726,
#        1184.88231726, 1004.04885309,  912.21332525,  586.05159189,
#        1184.88231726, 1184.88231726,  817.67071974, 1184.88231726,
#        1549.38683709,  725.8351919 ,  681.33622374,  817.67071974,
#         817.67071974, 1184.88231726,  686.88089292, 1184.88231726,
#         545.00172774, 1184.88231726,  545.00172774, 1184.88231726,
#         542.22939314,  545.00172774, 1184.88231726, 1730.22030126,
#        1184.88231726,  731.37986109,  681.33622374, 2102.97656796,
#        1184.88231726,  998.5041839 ,  725.8351919 ,  681.33622374,
#        1735.76497044,  542.22939314,  817.67071974,  545.00172774,
#        1184.88231726,  912.21332525, 1184.88231726, 1184.88231726,
#        1004.04885309,  681.33622374, 2102.97656796,  542.22939314,
#        3193.65253596,  542.22939314, 1184.88231726, 1184.88231726,
#         725.8351919 ,  542.22939314, 1184.88231726, 1184.88231726,
#         817.67071974,  586.05159189,  542.22939314,  912.21332525,
#         545.00172774,  562.75432522, 1184.88231726,  912.21332525,
#         586.05159189, 1184.88231726,  542.22939314,  544.10984709,
#        1184.88231726, 1184.88231726, 1735.76497044,  632.64612523,
#         542.22939314,  725.8351919 , 1184.88231726, 1074.22030058,
#        1004.04885309,  542.22939314, 2108.52123714, 1184.88231726,
#        1184.88231726,  817.67071974,  998.5041839 ,  542.22939314,
#        1004.04885309,  496.31162923, 1184.88231726, 1184.88231726,
#         449.71709589, 1090.33971174,  725.8351919 ,  823.21538892,
#         817.67071974,  542.22939314, 1004.04885309, 1184.88231726,
#         817.67071974, 1463.09597844, 1184.88231726, 1184.88231726,
#         562.75432522, 1184.88231726, 2102.97656796, 1184.88231726,
#         542.22939314, 1184.88231726, 1741.30963962, 1184.88231726,
#         586.05159189,  725.8351919 ,  542.22939314,  725.8351919 ,
#         725.8351919 , 2102.97656796,  542.22939314,  542.22939314,
#        1735.76497044, 1184.88231726, 1184.88231726,  903.71637599,
#        1090.33971174, 1184.88231726, 1184.88231726,  542.22939314,
#        1184.88231726, 1735.76497044, 2102.97656796, 1184.88231726,
#         545.00172774, 1004.04885309, 1004.04885309,  912.21332525,
#        1048.54782125, 1184.88231726, 1741.30963962,  725.8351919 ,
#        1090.33971174,  817.67071974, 1004.04885309, 1004.04885309,
#        1741.30963962, 1184.88231726, 1184.88231726, 1557.63858396,
#         542.22939314, 1190.42698644, 1190.42698644, 1735.76497044,
#        1184.88231726, 1184.88231726, 1004.04885309,  542.22939314,
#         542.22939314, 2102.97656796, 1184.88231726, 1184.88231726,
#        1048.54782125, 1184.88231726, 1557.63858396])

# %%
sample = pd.read_csv("data/com_sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_euros
# 0        539          650
# 1        327          650
# 2        563          650
# 3         13          650
# 4        935          500

# %%
submission = pd.DataFrame({"laptop_ID": sample['laptop_ID'], "Price_euros": predictions_submit})
submission.head()
# Out:
#    laptop_ID  Price_euros
# 0        539  1190.426986
# 1        327  1184.882317
# 2        563   586.051592
# 3         13  1730.220301
# 4        935  1184.882317

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# paso el checkeador que nos proporciona Juan

# %%
import urllib.request
from PIL import Image

def chequeator(df_to_submit,version):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit['laptop_ID'].all() == sample['laptop_ID'].all():
                print("You're ready to submit!")
                submission.to_csv(f"data/submission_{version}.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
chequeator(submission,2)
# Out:
# You're ready to submit!
