# %%
import pandas as pd
import numpy as np

# %%
def ini_inspec(df):
    # Tamaño y estructura de los datos
    print("=== TAMAÑO Y ESTRUCTURA DE LOS DATOS ===")
    print(f"Número total de registros: {df.shape[0]}")
    print(f"Número de columnas: {df.shape[1]}")
    print(f"Uso de memoria: {df.memory_usage().sum() / 1024:.2f} KB")
    print("\n")

    # Tipos de datos y nombres de columnas
    print("=== TIPOS DE DATOS Y NOMBRES DE COLUMNAS ===")
    print(df.dtypes)
    print("\n")
    print("Información detallada del DataFrame:")
    print(df.info())
    print("\n")

    # Identificación de problemas iniciales
    print("=== IDENTIFICACIÓN DE PROBLEMAS INICIALES ===")
    print(f"Número de filas duplicadas: {df.duplicated().sum()}")
    print("\nValores nulos por columna:")
    print(df.isnull().sum())

    # Mostrar las primeras filas para verificar la estructura
    print("\nPrimeras filas del dataset:")
    print(df.head())

    # Mostrar las ultimas filas para verificar la estructura
    print("\nÚltimas filas del dataset:")
    print(df.tail(10))

# %%
#verifico con ejemplo si funciona
alimentos= pd.read_csv ('food_100.csv')

# %%
alimentos

# %%
df = alimentos.copy ()

# %%
ini_inspec (df)
# Out:
# === TAMAÑO Y ESTRUCTURA DE LOS DATOS ===
# Número total de registros: 100
# Número de columnas: 164
# Uso de memoria: 128.25 KB
#
#
# === TIPOS DE DATOS Y NOMBRES DE COLUMNAS ===
# Unnamed: 0                   int64
# code                         int64
# url                         object
# creator                     object
# created_t                    int64
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 164, dtype: object
#
#
# Información detallada del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 164 entries, Unnamed: 0 to water-hardness_100g
# dtypes: float64(125), int64(4), object(35)
# memory usage: 128.3+ KB
# None
#
#
# === IDENTIFICACIÓN DE PROBLEMAS INICIALES ===
# Número de filas duplicadas: 0
#
# Valores nulos por columna:
# Unnamed: 0                   0
# code                         0
# url                          0
# creator                      0
# created_t                    0
#                           ...
# carbon-footprint_100g      100
# nutrition-score-fr_100g     63
# nutrition-score-uk_100g     63
# glycemic-index_100g        100
# water-hardness_100g        100
# Length: 164, dtype: int64
#
# Primeras filas del dataset:
#    Unnamed: 0   code                                                url  \
# 0           0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1           1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2           2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3           3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4           4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#    generic_name  ... fruits-vegetables-nuts_100g  \
# 0           NaN  ...                         NaN
# 1           NaN  ...                         NaN
# 2           NaN  ...                         NaN
# 3           NaN  ...                         NaN
# 4           NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# 0                     NaN                  NaN                  NaN
# 1                    14.0                  NaN                  NaN
# 2                     0.0                  NaN                  NaN
# 3                    12.0                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
#
# [5 rows x 164 columns]
#
# Últimas filas del dataset:
#     Unnamed: 0   code                                                url  \
# 90          90  34456  http://world-en.openfoodfacts.org/product/0000...
# 91          91  34470  http://world-en.openfoodfacts.org/product/0000...
# 92          92  34548  http://world-en.openfoodfacts.org/product/0000...
# 93          93  34562  http://world-en.openfoodfacts.org/product/0000...
# 94          94  34623  http://world-en.openfoodfacts.org/product/0000...
# 95          95  34715  http://world-en.openfoodfacts.org/product/0000...
# 96          96  34784  http://world-en.openfoodfacts.org/product/0000...
# 97          97  34791  http://world-en.openfoodfacts.org/product/0000...
# 98          98  35071  http://world-en.openfoodfacts.org/product/0000...
# 99          99  35170  http://world-en.openfoodfacts.org/product/0000...
#
#             creator   created_t      created_datetime  last_modified_t  \
# 90  usda-ndb-import  1489055733  2017-03-09T10:35:33Z       1489055734
# 91  usda-ndb-import  1489055724  2017-03-09T10:35:24Z       1489055724
# 92  usda-ndb-import  1489055678  2017-03-09T10:34:38Z       1489055678
# 93  usda-ndb-import  1489055706  2017-03-09T10:35:06Z       1489055707
# 94  usda-ndb-import  1489055651  2017-03-09T10:34:11Z       1489055652
# 95  usda-ndb-import  1489055715  2017-03-09T10:35:15Z       1489055715
# 96  usda-ndb-import  1489138485  2017-03-10T09:34:45Z       1489138485
# 97  usda-ndb-import  1489055720  2017-03-09T10:35:20Z       1489055720
# 98  usda-ndb-import  1489138484  2017-03-10T09:34:44Z       1489138484
# 99  usda-ndb-import  1489138488  2017-03-10T09:34:48Z       1489138488
#
#    last_modified_datetime                         product_name  generic_name  \
# 90   2017-03-09T10:35:34Z                Foods, Deluxe Nut Mix           NaN
# 91   2017-03-09T10:35:24Z  Foods, Honey Roast Nuts & Fruit Mix           NaN
# 92   2017-03-09T10:34:38Z                  Organic Raw Walnuts           NaN
# 93   2017-03-09T10:35:07Z          Organic Raw Sunflower Seeds           NaN
# 94   2017-03-09T10:34:12Z                    Organic Trail Mix           NaN
# 95   2017-03-09T10:35:15Z                 Organic Pecan Halves           NaN
# 96   2017-03-10T09:34:45Z         Unsalted Dry Roasted Almonds           NaN
# 97   2017-03-09T10:35:20Z            Organic Raw Pumpkin Seeds           NaN
# 98   2017-03-10T09:34:44Z       Organic Extra Virgin Olive Oil           NaN
# 99   2017-03-10T09:34:48Z                        Liquid Aminos           NaN
#
#     ... fruits-vegetables-nuts_100g fruits-vegetables-nuts-estimate_100g  \
# 90  ...                         NaN                                  NaN
# 91  ...                         NaN                                  NaN
# 92  ...                         NaN                                  NaN
# 93  ...                         NaN                                  NaN
# 94  ...                         NaN                                  NaN
# 95  ...                         NaN                                  NaN
# 96  ...                         NaN                                  NaN
# 97  ...                         NaN                                  NaN
# 98  ...                         NaN                                  NaN
# 99  ...                         NaN                                  NaN
#
#    collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 90                              NaN        NaN             NaN
# 91                              NaN        NaN             NaN
# 92                              NaN        NaN             NaN
# 93                              NaN        NaN             NaN
# 94                              NaN        NaN             NaN
# 95                              NaN        NaN             NaN
# 96                              NaN        NaN             NaN
# 97                              NaN        NaN             NaN
# 98                              NaN        NaN             NaN
# 99                              NaN        NaN             NaN
#
#    carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 90                   NaN                    11.0                    11.0
# 91                   NaN                    11.0                    11.0
# 92                   NaN                     NaN                     NaN
# 93                   NaN                     NaN                     NaN
# 94                   NaN                    10.0                    10.0
# 95                   NaN                     NaN                     NaN
# 96                   NaN                     NaN                     NaN
# 97                   NaN                    12.0                    12.0
# 98                   NaN                     NaN                     NaN
# 99                   NaN                     NaN                     NaN
#
#     glycemic-index_100g  water-hardness_100g
# 90                  NaN                  NaN
# 91                  NaN                  NaN
# 92                  NaN                  NaN
# 93                  NaN                  NaN
# 94                  NaN                  NaN
# 95                  NaN                  NaN
# 96                  NaN                  NaN
# 97                  NaN                  NaN
# 98                  NaN                  NaN
# 99                  NaN                  NaN
#
# [10 rows x 164 columns]

# %%
def crear_tabla_resumen:
