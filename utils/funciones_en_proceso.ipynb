# %%
import pandas as pd
import numpy as np

# %%
def ini_inspec(df):
    # Tamaño y estructura de los datos
    print("=== TAMAÑO Y ESTRUCTURA DE LOS DATOS ===")
    print(f"Número total de registros (filas): {df.shape[0]}")
    print(f"Número de columnas: {df.shape[1]}")
    print(f"Uso de memoria: {df.memory_usage().sum() / 1024:.2f} KB")
    print("\n")

    # Tipos de datos y nombres de columnas
    print("=== TIPOS DE DATOS Y NOMBRES DE COLUMNAS ===")
    print(df.dtypes)
    print("\n")
    print("Información detallada del DataFrame:")
    print(df.info())
    print("\n")

    # Identificación de problemas iniciales
    print("=== IDENTIFICACIÓN DE PROBLEMAS INICIALES ===")
    print(f"Número de filas duplicadas: {df.duplicated().sum()}")
    print("\nValores nulos por columna:")
    print(df.isnull().sum())

    # Mostrar las primeras filas para verificar la estructura
    print("\nPrimeras filas del dataset:")
    print(df.head())

    # Mostrar las ultimas filas para verificar la estructura
    print("\nÚltimas filas del dataset:")
    print(df.tail(10))

# %%
#verifico con ejemplo si funciona
alimentos= pd.read_csv ('food_100.csv', index_col=0)

# %%
alimentos.axes[1]
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
alimentos.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#    generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0           NaN      1kg  ...                         NaN
# 1           NaN      NaN  ...                         NaN
# 2           NaN      NaN  ...                         NaN
# 3           NaN      NaN  ...                         NaN
# 4           NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#    nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# 0                      NaN                  NaN                  NaN
# 1                     14.0                  NaN                  NaN
# 2                      0.0                  NaN                  NaN
# 3                     12.0                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
# [5 rows x 163 columns]

# %%
df = alimentos.copy ()

# %%
df.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#    generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0           NaN      1kg  ...                         NaN
# 1           NaN      NaN  ...                         NaN
# 2           NaN      NaN  ...                         NaN
# 3           NaN      NaN  ...                         NaN
# 4           NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#    nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# 0                      NaN                  NaN                  NaN
# 1                     14.0                  NaN                  NaN
# 2                      0.0                  NaN                  NaN
# 3                     12.0                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
# [5 rows x 163 columns]

# %%
ini_inspec (df)
# Out:
# === TAMAÑO Y ESTRUCTURA DE LOS DATOS ===
# Número total de registros (filas): 100
# Número de columnas: 163
# Uso de memoria: 128.12 KB
#
#
# === TIPOS DE DATOS Y NOMBRES DE COLUMNAS ===
# code                         int64
# url                         object
# creator                     object
# created_t                    int64
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 163, dtype: object
#
#
# Información detallada del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(125), int64(3), object(35)
# memory usage: 128.1+ KB
# None
#
#
# === IDENTIFICACIÓN DE PROBLEMAS INICIALES ===
# Número de filas duplicadas: 0
#
# Valores nulos por columna:
# code                         0
# url                          0
# creator                      0
# created_t                    0
# created_datetime             0
#                           ...
# carbon-footprint_100g      100
# nutrition-score-fr_100g     63
# nutrition-score-uk_100g     63
# glycemic-index_100g        100
# water-hardness_100g        100
# Length: 163, dtype: int64
#
# Primeras filas del dataset:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#    generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0           NaN      1kg  ...                         NaN
# 1           NaN      NaN  ...                         NaN
# 2           NaN      NaN  ...                         NaN
# 3           NaN      NaN  ...                         NaN
# 4           NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#    nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# 0                      NaN                  NaN                  NaN
# 1                     14.0                  NaN                  NaN
# 2                      0.0                  NaN                  NaN
# 3                     12.0                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
# [5 rows x 163 columns]
#
# Últimas filas del dataset:
#      code                                                url          creator  \
# 90  34456  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 91  34470  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 92  34548  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 93  34562  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 94  34623  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 95  34715  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 96  34784  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 97  34791  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 98  35071  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
# 99  35170  http://world-en.openfoodfacts.org/product/0000...  usda-ndb-import
#
#      created_t      created_datetime  last_modified_t last_modified_datetime  \
# 90  1489055733  2017-03-09T10:35:33Z       1489055734   2017-03-09T10:35:34Z
# 91  1489055724  2017-03-09T10:35:24Z       1489055724   2017-03-09T10:35:24Z
# 92  1489055678  2017-03-09T10:34:38Z       1489055678   2017-03-09T10:34:38Z
# 93  1489055706  2017-03-09T10:35:06Z       1489055707   2017-03-09T10:35:07Z
# 94  1489055651  2017-03-09T10:34:11Z       1489055652   2017-03-09T10:34:12Z
# 95  1489055715  2017-03-09T10:35:15Z       1489055715   2017-03-09T10:35:15Z
# 96  1489138485  2017-03-10T09:34:45Z       1489138485   2017-03-10T09:34:45Z
# 97  1489055720  2017-03-09T10:35:20Z       1489055720   2017-03-09T10:35:20Z
# 98  1489138484  2017-03-10T09:34:44Z       1489138484   2017-03-10T09:34:44Z
# 99  1489138488  2017-03-10T09:34:48Z       1489138488   2017-03-10T09:34:48Z
#
#                            product_name  generic_name quantity  ...  \
# 90                Foods, Deluxe Nut Mix           NaN      NaN  ...
# 91  Foods, Honey Roast Nuts & Fruit Mix           NaN      NaN  ...
# 92                  Organic Raw Walnuts           NaN      NaN  ...
# 93          Organic Raw Sunflower Seeds           NaN      NaN  ...
# 94                    Organic Trail Mix           NaN      NaN  ...
# 95                 Organic Pecan Halves           NaN      NaN  ...
# 96         Unsalted Dry Roasted Almonds           NaN      NaN  ...
# 97            Organic Raw Pumpkin Seeds           NaN      NaN  ...
# 98       Organic Extra Virgin Olive Oil           NaN      NaN  ...
# 99                        Liquid Aminos           NaN      NaN  ...
#
#    fruits-vegetables-nuts_100g fruits-vegetables-nuts-estimate_100g  \
# 90                         NaN                                  NaN
# 91                         NaN                                  NaN
# 92                         NaN                                  NaN
# 93                         NaN                                  NaN
# 94                         NaN                                  NaN
# 95                         NaN                                  NaN
# 96                         NaN                                  NaN
# 97                         NaN                                  NaN
# 98                         NaN                                  NaN
# 99                         NaN                                  NaN
#
#    collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 90                              NaN        NaN             NaN
# 91                              NaN        NaN             NaN
# 92                              NaN        NaN             NaN
# 93                              NaN        NaN             NaN
# 94                              NaN        NaN             NaN
# 95                              NaN        NaN             NaN
# 96                              NaN        NaN             NaN
# 97                              NaN        NaN             NaN
# 98                              NaN        NaN             NaN
# 99                              NaN        NaN             NaN
#
#    carbon-footprint_100g nutrition-score-fr_100g  nutrition-score-uk_100g  \
# 90                   NaN                    11.0                     11.0
# 91                   NaN                    11.0                     11.0
# 92                   NaN                     NaN                      NaN
# 93                   NaN                     NaN                      NaN
# 94                   NaN                    10.0                     10.0
# 95                   NaN                     NaN                      NaN
# 96                   NaN                     NaN                      NaN
# 97                   NaN                    12.0                     12.0
# 98                   NaN                     NaN                      NaN
# 99                   NaN                     NaN                      NaN
#
#     glycemic-index_100g  water-hardness_100g
# 90                  NaN                  NaN
# 91                  NaN                  NaN
# 92                  NaN                  NaN
# 93                  NaN                  NaN
# 94                  NaN                  NaN
# 95                  NaN                  NaN
# 96                  NaN                  NaN
# 97                  NaN                  NaN
# 98                  NaN                  NaN
# 99                  NaN                  NaN
#
# [10 rows x 163 columns]

# %%
#función para Análisis Estructural, Análisis técnico 
def crear_tabla_resumen(df):
    resumen = []
    #quiero crear un nuevo df con las columnas como filas, 
    for col in df.columns:
        # Extraer la información de cada columna del DF original
        tipo_dato = df[col].dtype
        cardinalidad = df[col].nunique()

        if tipo_dato in ['object', 'string']:  # or df[col].nunique() < 10: #muy pocos vaores únicos
            categoria_dato = 'Categórica Nominal'
            if cardinalidad == 2:
                categoria_dato = 'Binaria'
        elif tipo_dato in ['int64','int32','int16','float64','float32','float16']:  # Columnas numéricas
            if cardinalidad == len(df):
                categoria_dato = 'Indice Numérico'
            else: 
                if df[col].dtype in ['float64', 'float32', 'float16']:
                    categoria_dato = 'Numérica Continua'
                else:
                    categoria_dato = 'Numérica Discreta'

        else:
            categoria_dato = 'Desconocida'        

        porcentaje_cardinalidad = (cardinalidad / len(df)) * 100

        valores_faltantes = df[col].isna().sum()
        porcentaje_valores_faltantes = (valores_faltantes / len(df)) * 100

        resumen.append({
            'Columna': col,
            'Tipo de dato': tipo_dato,
            'Categoría': categoria_dato,
            'Cardinalidad': cardinalidad,
            '% Cardinalidad': porcentaje_cardinalidad,
            'Valores faltantes': valores_faltantes,
            '% Valores faltantes': porcentaje_valores_faltantes,
            })

    #Convertir el resumen en un DataFrame
    resumen_df = pd.DataFrame(resumen)
    return resumen_df.set_index('Columna')

# %%
crear_tabla_resumen (df)
# Out:
#                         Tipo de dato           Categoría  Cardinalidad  \
# Columna
# code                           int64     Indice Numérico           100
# url                           object  Categórica Nominal           100
# creator                       object  Categórica Nominal             6
# created_t                      int64   Numérica Discreta            47
# created_datetime              object  Categórica Nominal            47
# ...                              ...                 ...           ...
# carbon-footprint_100g        float64   Numérica Continua             0
# nutrition-score-fr_100g      float64   Numérica Continua            15
# nutrition-score-uk_100g      float64   Numérica Continua            15
# glycemic-index_100g          float64   Numérica Continua             0
# water-hardness_100g          float64   Numérica Continua             0
#
#                          % Cardinalidad  Valores faltantes  \
# Columna
# code                              100.0                  0
# url                               100.0                  0
# creator                             6.0                  0
# created_t                          47.0                  0
# created_datetime                   47.0                  0
# ...                                 ...                ...
# carbon-footprint_100g               0.0                100
# nutrition-score-fr_100g            15.0                 63
# nutrition-score-uk_100g            15.0                 63
# glycemic-index_100g                 0.0                100
# water-hardness_100g                 0.0                100
#
#                          % Valores faltantes
# Columna
# code                                     0.0
# url                                      0.0
# creator                                  0.0
# created_t                                0.0
# created_datetime                         0.0
# ...                                      ...
# carbon-footprint_100g                  100.0
# nutrition-score-fr_100g                 63.0
# nutrition-score-uk_100g                 63.0
# glycemic-index_100g                    100.0
# water-hardness_100g                    100.0
#
# [163 rows x 6 columns]

# %%
def numericas(df):
    resumen = []

    for col in df.columns:
        # Verificar si la columna es numérica
        if pd.api.types.is_numeric_dtype(df[col]):          #las columnas no numericas se omiten
            data = df[col].dropna()  # Ignorar valores NaN para los cálculos
            count = data.count()
            mean = data.mean()
            median = data.median()
            mode = data.mode().iloc[0] if not data.mode().empty else np.nan
            std = data.std()
            min_val = data.min()
            q25 = data.quantile(0.25)
            q50 = data.quantile(0.50)  # Igual a la mediana
            q75 = data.quantile(0.75)
            max_val = data.max()
            iqr = q75 - q25
            data_range = max_val - min_val
            variance = data.var()
            std_dev = std
            skewness = data.skew()
            kurtosis = data.kurtosis()
            missing = df[col].isna().sum()
            missing_percent = (missing / len(df)) * 100

            resumen.append({
                "columna": col,
                "count": count,
                "mean": mean,
                "median": median,
                "mode": mode,
                "std": std,
                "min": min_val,
                "25%": q25,
                "50%": q50,
                "75%": q75,
                "max": max_val,
                "iqr": iqr,
                "range": data_range,
                "variance": variance,
                "std_dev": std_dev,
                "skewness": skewness,
                "kurtosis": kurtosis,
                "missing": missing,
                "missing_percent": missing_percent
            })
    
    # Convertir el resumen en un DataFrame
    resumen_df = pd.DataFrame(resumen)
    return resumen_df.set_index("columna")

# %%
numericas (df)
# Out:
#                          count          mean        median          mode  \
# columna
# code                       100  2.524392e+04  2.862150e+04  3.087000e+03
# created_t                  100  1.488157e+09  1.489056e+09  1.489056e+09
# last_modified_t            100  1.488157e+09  1.489056e+09  1.489056e+09
# generic_name                 0           NaN           NaN           NaN
# origins                      0           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# carbon-footprint_100g        0           NaN           NaN           NaN
# nutrition-score-fr_100g     37  9.108108e+00  1.100000e+01  0.000000e+00
# nutrition-score-uk_100g     37  9.108108e+00  1.100000e+01  0.000000e+00
# glycemic-index_100g          0           NaN           NaN           NaN
# water-hardness_100g          0           NaN           NaN           NaN
#
#                                   std           min           25%  \
# columna
# code                     8.257775e+03  3.087000e+03  1.836750e+04
# created_t                6.895563e+06  1.434531e+09  1.489056e+09
# last_modified_t          6.895160e+06  1.434536e+09  1.489056e+09
# generic_name                      NaN           NaN           NaN
# origins                           NaN           NaN           NaN
# ...                               ...           ...           ...
# carbon-footprint_100g             NaN           NaN           NaN
# nutrition-score-fr_100g  6.628155e+00 -6.000000e+00  6.000000e+00
# nutrition-score-uk_100g  6.628155e+00 -6.000000e+00  6.000000e+00
# glycemic-index_100g               NaN           NaN           NaN
# water-hardness_100g               NaN           NaN           NaN
#
#                                   50%           75%           max       iqr  \
# columna
# code                     2.862150e+04  3.332675e+04  3.517000e+04  14959.25
# created_t                1.489056e+09  1.489056e+09  1.502444e+09     70.50
# last_modified_t          1.489056e+09  1.489056e+09  1.502444e+09     70.50
# generic_name                      NaN           NaN           NaN       NaN
# origins                           NaN           NaN           NaN       NaN
# ...                               ...           ...           ...       ...
# carbon-footprint_100g             NaN           NaN           NaN       NaN
# nutrition-score-fr_100g  1.100000e+01  1.400000e+01  2.600000e+01      8.00
# nutrition-score-uk_100g  1.100000e+01  1.400000e+01  2.600000e+01      8.00
# glycemic-index_100g               NaN           NaN           NaN       NaN
# water-hardness_100g               NaN           NaN           NaN       NaN
#
#                               range      variance       std_dev  skewness  \
# columna
# code                        32083.0  6.819084e+07  8.257775e+03 -0.394837
# created_t                67913562.0  4.754879e+13  6.895563e+06 -5.718772
# last_modified_t          67908514.0  4.754324e+13  6.895160e+06 -5.718378
# generic_name                    NaN           NaN           NaN       NaN
# origins                         NaN           NaN           NaN       NaN
# ...                             ...           ...           ...       ...
# carbon-footprint_100g           NaN           NaN           NaN       NaN
# nutrition-score-fr_100g        32.0  4.393243e+01  6.628155e+00 -0.211067
# nutrition-score-uk_100g        32.0  4.393243e+01  6.628155e+00 -0.211067
# glycemic-index_100g             NaN           NaN           NaN       NaN
# water-hardness_100g             NaN           NaN           NaN       NaN
#
#                           kurtosis  missing  missing_percent
# columna
# code                     -0.883642        0              0.0
# created_t                40.854776        0              0.0
# last_modified_t          40.849992        0              0.0
# generic_name                   NaN      100            100.0
# origins                        NaN      100            100.0
# ...                            ...      ...              ...
# carbon-footprint_100g          NaN      100            100.0
# nutrition-score-fr_100g   0.250679       63             63.0
# nutrition-score-uk_100g   0.250679       63             63.0
# glycemic-index_100g            NaN      100            100.0
# water-hardness_100g            NaN      100            100.0
#
# [128 rows x 18 columns]

# %%
def categoricas(df):
    resumen = []

    for col in df.columns:
        # Verificar si la columna no es numérica
        if not pd.api.types.is_numeric_dtype(df[col]):
            count = df[col].count()
            unique = df[col].nunique()
            top = df[col].mode().iloc[0] if not df[col].mode().empty else np.nan
            freq = df[col].value_counts().iloc[0] if not df[col].value_counts().empty else np.nan
            missing = df[col].isna().sum()
            missing_percent = (missing / len(df)) * 100

            resumen.append({
                "columna": col,
                "count": count,
                "unique": unique,
                "top": top,
                "freq": freq,
                "missing": missing,
                "missing_percent": missing_percent
            })
    
    # Convertir el resumen en un DataFrame
    resumen_df = pd.DataFrame(resumen)
    return resumen_df.set_index("columna")

# %%
categoricas (df)
# Out:
#                                             count  unique  \
# columna
# url                                           100     100
# creator                                       100       6
# created_datetime                              100      47
# last_modified_datetime                        100      51
# product_name                                   99      99
# quantity                                        5       5
# packaging                                       1       1
# packaging_tags                                  1       1
# brands                                         96      30
# brands_tags                                    96      30
# categories                                      1       1
# categories_tags                                 1       1
# categories_en                                   1       1
# countries                                     100       4
# countries_tags                                100       3
# countries_en                                  100       3
# ingredients_text                               95      94
# traces                                          1       1
# traces_tags                                     1       1
# traces_en                                       1       1
# serving_size                                   94      39
# additives                                      95      93
# additives_tags                                 16      12
# additives_en                                   16      12
# ingredients_that_may_be_from_palm_oil_tags      1       1
# nutrition_grade_fr                             37       5
# pnns_groups_1                                   1       1
# pnns_groups_2                                   1       1
# states                                        100       7
# states_tags                                   100       7
# states_en                                     100       7
# main_category                                   1       1
# main_category_en                                1       1
# image_url                                       2       2
# image_small_url                                 2       2
#
#                                                                                           top  \
# columna
# url                                         http://world-en.openfoodfacts.org/product/0000...
# creator                                                                       usda-ndb-import
# created_datetime                                                         2017-03-09T10:34:38Z
# last_modified_datetime                                                   2017-03-09T10:34:38Z
# product_name                                                             10-Grain Pancake Mix
# quantity                                                                                  1kg
# packaging                                                                           plastique
# packaging_tags                                                                      plastique
# brands                                                                                   Unfi
# brands_tags                                                                              unfi
# categories                                                                      Filet de bœuf
# categories_tags                                                             fr:filet-de-boeuf
# categories_en                                                               fr:Filet-de-boeuf
# countries                                                                                  US
# countries_tags                                                               en:united-states
# countries_en                                                                    United States
# ingredients_text                                   Organic refined durum semolina wheat flour
# traces                                                                            milk, egg,
# traces_tags                                                                   en:eggs,en:milk
# traces_en                                                                           Eggs,Milk
# serving_size                                                                  30 g (0.25 cup)
# additives                                    [ organic-coconut -> en:organic-coconut  ]  [...
# additives_tags                                                               en:e322,en:e322i
# additives_en                                                E322 - Lecithins,E322i - Lecithin
# ingredients_that_may_be_from_palm_oil_tags  e481-stearoyl-2-lactylate-de-sodium,e472e-este...
# nutrition_grade_fr                                                                          d
# pnns_groups_1                                                                         unknown
# pnns_groups_2                                                                         unknown
# states                                      en:to-be-completed, en:nutrition-facts-complet...
# states_tags                                 en:to-be-completed,en:nutrition-facts-complete...
# states_en                                   To be completed,Nutrition facts completed,Ingr...
# main_category                                                               fr:filet-de-boeuf
# main_category_en                                                            fr:Filet-de-boeuf
# image_url                                   http://en.openfoodfacts.org/images/products/00...
# image_small_url                             http://en.openfoodfacts.org/images/products/00...
#
#                                             freq  missing  missing_percent
# columna
# url                                            1        0              0.0
# creator                                       94        0              0.0
# created_datetime                               7        0              0.0
# last_modified_datetime                         7        0              0.0
# product_name                                   1        1              1.0
# quantity                                       1       95             95.0
# packaging                                      1       99             99.0
# packaging_tags                                 1       99             99.0
# brands                                        21        4              4.0
# brands_tags                                   21        4              4.0
# categories                                     1       99             99.0
# categories_tags                                1       99             99.0
# categories_en                                  1       99             99.0
# countries                                     94        0              0.0
# countries_tags                                94        0              0.0
# countries_en                                  94        0              0.0
# ingredients_text                               2        5              5.0
# traces                                         1       99             99.0
# traces_tags                                    1       99             99.0
# traces_en                                      1       99             99.0
# serving_size                                  12        6              6.0
# additives                                      2        5              5.0
# additives_tags                                 5       84             84.0
# additives_en                                   5       84             84.0
# ingredients_that_may_be_from_palm_oil_tags     1       99             99.0
# nutrition_grade_fr                            18       63             63.0
# pnns_groups_1                                  1       99             99.0
# pnns_groups_2                                  1       99             99.0
# states                                        93        0              0.0
# states_tags                                   93        0              0.0
# states_en                                     93        0              0.0
# main_category                                  1       99             99.0
# main_category_en                               1       99             99.0
# image_url                                      1       98             98.0
# image_small_url                                1       98             98.0
