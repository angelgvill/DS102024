# %% [markdown]
# # Los pingüinos de Palmer

# %% [markdown]
# ![](pinguinosPalmer)

# %% [markdown]
# Este conjunto de datos contiene información acerca de pingüinos que habitan en las Islas Palmer, en la Península Antártica. Las espeies incluidas son Adelie,

# %% [markdown]
# # Librerías

# %%
#Tratamiento de datos
import numpy as numpy
import pandas as np

#Gráficos


#Estadísticas
import scipy

# %% [markdown]
# # Carga de datos

# %%
pin = pd.read_csv()
