# %% [markdown]
# ## Ejercicio 1: Ortogonalidad

# %% [markdown]
# Definir una función en python que detecte si dos vectores son ortogonales

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def vector_norm(vector):
    squares = [element**2 for element in vector]
    return sum(squares)**0.5

print("||", u, "|| =")
vector_norm(u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2     squares = [element**2 for element in vector]
#       3     return sum(squares)**0.5
# ----> 5 print("||", u, "|| =")
#       6 vector_norm(u)
#
# NameError: name 'u' is not defined

# %%
import numpy as np
def son_ortogonales(u,v):
  #completa con tu código aquí
  if vector_norm(u) == 0:
    return (f'vector u norma cero')
  if vector_norm(v) == 0:
    return (f'vector v norma cero')
  if np.dot(u,v) == 0:
    return (f'Los vectores son ortogonales (producto escalar cero)')
  else:
    return (f'Los vectores no son orgononales (producto escalar no nulo), {np.dot(u,v)}')

u = np.array([2, 0])
v = np.array([0, 4])
print("||", u, "|| =")
vector_norm(u)

print("||", v, "|| =")
vector_norm(v)

son_ortogonales (u,v)

# %% [markdown]
# ## Ejercicio 2: Desplazamiento

# %% [markdown]
# Definir una función en python que reciba como parámetro las cuatro esquinas de un cuadrilátero y las desplace 5 unidades hacia arriba y 7 unidades a la izquierda

# %%
def desplazar_puntos(a,b,c,d):
  #completá con tu código aquí
  a_ = a + np.array([-7,5])
  b_ = b + np.array([-7,5])
  c_ = c + np.array([-7,5])
  d_ = d + np.array([-7,5])
  print (f'tus coordenadasde las esquinas eran {a,b,c,d}')
  print (f'tus coordenadasde desplazadas son {a_,b_,c_,d_}')

# %%
desplazar_puntos ([2,2],[6,7], [3,12], [7,12])
# Out:
# tus coordenadasde las esquinas eran ([2, 2], [6, 7], [3, 12], [7, 12])
# tus coordenadasde desplazadas son (array([-5,  7]), array([-1, 12]), array([-4, 17]), array([ 0, 17]))

# %%
def plot_vectores_mov_2d(vector2d:np.array, origin:list=[0, 0], **options) -> None:
    print(f'voy a dibujarte el movimiento en 2D para que quede más claro')
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)

# %%
plot_vectores_mov_2d(u, color="r")
plot_vectores_mov_2d(v, color="b")
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()

# %% [markdown]
# Ejecutar la siguiente celda descomentando las lineas en verde para verificar su funcionamiento.

# %%
import matplotlib.pyplot as plt
a = np.array([1,1])
b = np.array([1,2])
c = np.array([2,3])
d = np.array([8,4])

x_coords, y_coords = zip(a,b,c,d,a)
plt.plot(x_coords, y_coords, "c--", x_coords, y_coords, "co")

#a_,b_,c_,d_ = desplazar_puntos(a,b,c,d)
#x_coords_b, y_coords_b = zip(a_,b_,c_,d_,a_)
#plt.plot(x_coords_b, y_coords_b, "b-", x_coords_b, y_coords_b, "bo")

plt.show()
